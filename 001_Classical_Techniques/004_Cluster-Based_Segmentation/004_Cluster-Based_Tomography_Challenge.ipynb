# %% [markdown]
# # Cluster-Based Segmentation - Tomography Challenge

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image = cv2.imread('images/ct-scan.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image)
plt.title('Tomography Challenge - Original')
plt.axis('off')

plt.show()

# %%
vectorized_image = image.reshape(-1, 3)
vectorized_image = np.float32(vectorized_image)

print(f'Image shape: {vectorized_image.shape}')
# Out:
# Image shape: (76964, 3)

# %%
CRITERIA = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 10, 1.0)

# %% [markdown]
# ## Example - Two regions:

# %%
# ret: Sum of the squared distance from each point to its centers.
# labels: The labels of each pixel in the image.
# centers: Array with the centroids.
ret, label, centers = cv2.kmeans(vectorized_image, 2, None, CRITERIA, 10, cv2.KMEANS_RANDOM_CENTERS)
centers = np.uint8(centers)
print(centers)
# Out:
# [[75 75 75]
#  [ 6  6  6]]

# %%
final_image = centers[label.flatten()]
final_image = final_image.reshape(image.shape)

plt.imshow(final_image)
plt.title('Tomography Challenge - Cluster-Based - Two regions')
plt.axis('off')

plt.show()

# %% [markdown]
# ## Example - Three regions:

# %%
# ret: Sum of the squared distance from each point to its centers.
# labels: The labels of each pixel in the image.
# centers: Array with the centroids.
ret, label, centers = cv2.kmeans(vectorized_image, 3, None, CRITERIA, 10, cv2.KMEANS_RANDOM_CENTERS)
centers = np.uint8(centers)
print(centers)
# Out:
# [[127 127 127]
#  [  5   5   5]
#  [ 65  65  65]]

# %%
final_image = centers[label.flatten()]
final_image = final_image.reshape(image.shape)

plt.imshow(final_image)
plt.title('Tomography Challenge - Cluster-Based - Three regions')
plt.axis('off')

plt.show()

# %% [markdown]
# ## Example - Four regions:

# %%
# ret: Sum of the squared distance from each point to its centers.
# labels: The labels of each pixel in the image.
# centers: Array with the centroids.
ret, label, centers = cv2.kmeans(vectorized_image, 4, None, CRITERIA, 10, cv2.KMEANS_RANDOM_CENTERS)
centers = np.uint8(centers)
print(centers)
# Out:
# [[  5   5   5]
#  [129 129 129]
#  [ 74  74  74]
#  [ 55  55  55]]

# %%
final_image = centers[label.flatten()]
final_image = final_image.reshape(image.shape)

plt.imshow(final_image)
plt.title('Tomography Challenge - Cluster-Based - Four regions')
plt.axis('off')

plt.show()

# %% [markdown]
# ## Example - Five regions:

# %%
# ret: Sum of the squared distance from each point to its centers.
# labels: The labels of each pixel in the image.
# centers: Array with the centroids.
ret, label, centers = cv2.kmeans(vectorized_image, 5, None, CRITERIA, 10, cv2.KMEANS_RANDOM_CENTERS)
centers = np.uint8(centers)
print(centers)
# Out:
# [[  5   5   5]
#  [115 115 115]
#  [152 152 152]
#  [ 72  72  72]
#  [ 53  53  53]]

# %%
final_image = centers[label.flatten()]
final_image = final_image.reshape(image.shape)

plt.imshow(final_image)
plt.title('Tomography Challenge - Cluster-Based - Five regions')
plt.axis('off')

plt.show()

# %% [markdown]
# ## Example - Six regions:

# %%
# ret: Sum of the squared distance from each point to its centers.
# labels: The labels of each pixel in the image.
# centers: Array with the centroids.
ret, label, centers = cv2.kmeans(vectorized_image, 6, None, CRITERIA, 10, cv2.KMEANS_RANDOM_CENTERS)
centers = np.uint8(centers)
print(centers)
# Out:
# [[  3   3   3]
#  [154 154 154]
#  [ 74  74  74]
#  [ 57  57  57]
#  [116 116 116]
#  [ 27  27  27]]

# %%
final_image = centers[label.flatten()]
final_image = final_image.reshape(image.shape)

plt.imshow(final_image)
plt.title('Tomography Challenge - Cluster-Based - Six regions')
plt.axis('off')

plt.show()

# %% [markdown]
# ## Example - Seven regions:

# %%
# ret: Sum of the squared distance from each point to its centers.
# labels: The labels of each pixel in the image.
# centers: Array with the centroids.
ret, label, centers = cv2.kmeans(vectorized_image, 7, None, CRITERIA, 10, cv2.KMEANS_RANDOM_CENTERS)
centers = np.uint8(centers)
print(centers)
# Out:
# [[ 79  79  79]
#  [154 154 154]
#  [ 65  65  65]
#  [117 117 117]
#  [  3   3   3]
#  [ 51  51  51]
#  [ 23  23  23]]

# %%
final_image = centers[label.flatten()]
final_image = final_image.reshape(image.shape)

plt.imshow(final_image)
plt.title('Tomography Challenge - Cluster-Based - Seven regions')
plt.axis('off')

plt.show()

# %% [markdown]
# # Cluster-Based Segmentation - Landscape

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image = cv2.imread('images/landscape.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image)
plt.title('Landscape - Original')
plt.axis('off')

plt.show()

# %%
vectorized_image = image.reshape(-1, 3)
vectorized_image = np.float32(vectorized_image)

print(f'Image shape: {vectorized_image.shape}')
# Out:
# Image shape: (241180, 3)

# %%
CRITERIA = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 10, 1.0)

# %% [markdown]
# ## Example - Two regions:

# %%
# ret: Sum of the squared distance from each point to its centers.
# labels: The labels of each pixel in the image.
# centers: Array with the centroids.
ret, label, centers = cv2.kmeans(vectorized_image, 2, None, CRITERIA, 10, cv2.KMEANS_RANDOM_CENTERS)
centers = np.uint8(centers)
print(centers)
# Out:
# [[165 192 206]
#  [ 84  94  46]]

# %%
final_image = centers[label.flatten()]
final_image = final_image.reshape(image.shape)

plt.imshow(final_image)
plt.title('Landscape - Cluster-Based - Two regions')
plt.axis('off')

plt.show()

# %% [markdown]
# ## Example - Three regions:

# %%
# ret: Sum of the squared distance from each point to its centers.
# labels: The labels of each pixel in the image.
# centers: Array with the centroids.
ret, label, centers = cv2.kmeans(vectorized_image, 3, None, CRITERIA, 10, cv2.KMEANS_RANDOM_CENTERS)
centers = np.uint8(centers)
print(centers)
# Out:
# [[ 69  79  40]
#  [165 192 206]
#  [ 95 106  52]]

# %%
final_image = centers[label.flatten()]
final_image = final_image.reshape(image.shape)

plt.imshow(final_image)
plt.title('Landscape - Cluster-Based - Three regions')
plt.axis('off')

plt.show()

# %% [markdown]
# ## Example - Four regions:

# %%
# ret: Sum of the squared distance from each point to its centers.
# labels: The labels of each pixel in the image.
# centers: Array with the centroids.
ret, label, centers = cv2.kmeans(vectorized_image, 4, None, CRITERIA, 10, cv2.KMEANS_RANDOM_CENTERS)
centers = np.uint8(centers)
print(centers)
# Out:
# [[165 192 206]
#  [ 93 104  49]
#  [ 68  78  40]
#  [132 137 129]]

# %%
final_image = centers[label.flatten()]
final_image = final_image.reshape(image.shape)

plt.imshow(final_image)
plt.title('Landscape - Cluster-Based - Four regions')
plt.axis('off')

plt.show()

# %% [markdown]
# ## Example - Five regions:

# %%
# ret: Sum of the squared distance from each point to its centers.
# labels: The labels of each pixel in the image.
# centers: Array with the centroids.
ret, label, centers = cv2.kmeans(vectorized_image, 5, None, CRITERIA, 10, cv2.KMEANS_RANDOM_CENTERS)
centers = np.uint8(centers)
print(centers)
# Out:
# [[ 69  79  40]
#  [175 195 202]
#  [133 139 132]
#  [ 94 105  50]
#  [153 189 212]]

# %%
final_image = centers[label.flatten()]
final_image = final_image.reshape(image.shape)

plt.imshow(final_image)
plt.title('Landscape - Cluster-Based - Five regions')
plt.axis('off')

plt.show()

# %% [markdown]
# ## Example - Six regions:

# %%
# ret: Sum of the squared distance from each point to its centers.
# labels: The labels of each pixel in the image.
# centers: Array with the centroids.
ret, label, centers = cv2.kmeans(vectorized_image, 6, None, CRITERIA, 10, cv2.KMEANS_RANDOM_CENTERS)
centers = np.uint8(centers)
print(centers)
# Out:
# [[175 198 209]
#  [126 132 121]
#  [150 187 211]
#  [ 67  77  39]
#  [ 92 103  48]
#  [171 186 191]]

# %%
final_image = centers[label.flatten()]
final_image = final_image.reshape(image.shape)

plt.imshow(final_image)
plt.title('Landscape - Cluster-Based - Six regions')
plt.axis('off')

plt.show()

# %% [markdown]
# ## Example - Seven regions:

# %%
# ret: Sum of the squared distance from each point to its centers.
# labels: The labels of each pixel in the image.
# centers: Array with the centroids.
ret, label, centers = cv2.kmeans(vectorized_image, 7, None, CRITERIA, 10, cv2.KMEANS_RANDOM_CENTERS)
centers = np.uint8(centers)
print(centers)
# Out:
# [[ 93 104  49]
#  [ 68  78  39]
#  [128 133 123]
#  [164 196 215]
#  [169 184 190]
#  [147 185 210]
#  [180 198 204]]

# %%
final_image = centers[label.flatten()]
final_image = final_image.reshape(image.shape)

plt.imshow(final_image)
plt.title('Landscape - Cluster-Based - Seven regions')
plt.axis('off')

plt.show()

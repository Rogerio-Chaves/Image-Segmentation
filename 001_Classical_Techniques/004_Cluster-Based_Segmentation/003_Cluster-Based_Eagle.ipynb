# %% [markdown]
# # Cluster-Based Segmentation - Eagle Challenge

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image = cv2.imread('images/eagle.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image)
plt.title('Eagle Challenge - Original')
plt.axis('off')

plt.show()

# %%
vectorized_image = image.reshape(-1, 3)
vectorized_image = np.float32(vectorized_image)

print(f'Image shape: {vectorized_image.shape}')
# Out:
# Image shape: (682500, 3)

# %%
CRITERIA = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 10, 1.0)

# %% [markdown]
# ## Example - Two regions:

# %%
# ret: Sum of the squared distance from each point to its centers.
# labels: The labels of each pixel in the image.
# centers: Array with the centroids.
ret, label, centers = cv2.kmeans(vectorized_image, 2, None, CRITERIA, 10, cv2.KMEANS_RANDOM_CENTERS)
centers = np.uint8(centers)
print(centers)
# Out:
# [[226 230 233]
#  [ 34  45  48]]

# %%
final_image = centers[label.flatten()]
final_image = final_image.reshape(image.shape)

plt.imshow(final_image)
plt.title('Eagle Challenge - Cluster-Based - Two regions')
plt.axis('off')

plt.show()

# %% [markdown]
# ## Example - Three regions:

# %%
# ret: Sum of the squared distance from each point to its centers.
# labels: The labels of each pixel in the image.
# centers: Array with the centroids.
ret, label, centers = cv2.kmeans(vectorized_image, 3, None, CRITERIA, 10, cv2.KMEANS_RANDOM_CENTERS)
centers = np.uint8(centers)
print(centers)
# Out:
# [[227 231 233]
#  [133 127 121]
#  [ 23  36  40]]

# %%
final_image = centers[label.flatten()]
final_image = final_image.reshape(image.shape)

plt.imshow(final_image)
plt.title('Eagle Challenge - Cluster-Based - Three regions')
plt.axis('off')

plt.show()

# %% [markdown]
# ## Example - Four regions:

# %%
# ret: Sum of the squared distance from each point to its centers.
# labels: The labels of each pixel in the image.
# centers: Array with the centroids.
ret, label, centers = cv2.kmeans(vectorized_image, 4, None, CRITERIA, 10, cv2.KMEANS_RANDOM_CENTERS)
centers = np.uint8(centers)
print(centers)
# Out:
# [[230 234 236]
#  [219 225 228]
#  [ 22  36  40]
#  [129 123 117]]

# %%
final_image = centers[label.flatten()]
final_image = final_image.reshape(image.shape)

plt.imshow(final_image)
plt.title('Eagle Challenge - Cluster-Based - Four regions')
plt.axis('off')

plt.show()

# %% [markdown]
# ## Example - Five regions:

# %%
# ret: Sum of the squared distance from each point to its centers.
# labels: The labels of each pixel in the image.
# centers: Array with the centroids.
ret, label, centers = cv2.kmeans(vectorized_image, 5, None, CRITERIA, 10, cv2.KMEANS_RANDOM_CENTERS)
centers = np.uint8(centers)
print(centers)
# Out:
# [[ 97  94  89]
#  [ 20  34  38]
#  [230 234 236]
#  [166 159 154]
#  [220 225 228]]

# %%
final_image = centers[label.flatten()]
final_image = final_image.reshape(image.shape)

plt.imshow(final_image)
plt.title('Eagle Challenge - Cluster-Based - Five regions')
plt.axis('off')

plt.show()

# %% [markdown]
# ## Example - Six regions:

# %%
# ret: Sum of the squared distance from each point to its centers.
# labels: The labels of each pixel in the image.
# centers: Array with the centroids.
ret, label, centers = cv2.kmeans(vectorized_image, 6, None, CRITERIA, 10, cv2.KMEANS_RANDOM_CENTERS)
centers = np.uint8(centers)
print(centers)
# Out:
# [[182 175 170]
#  [ 81  81  77]
#  [230 234 236]
#  [ 19  33  38]
#  [134 128 122]
#  [220 225 228]]

# %%
final_image = centers[label.flatten()]
final_image = final_image.reshape(image.shape)

plt.imshow(final_image)
plt.title('Eagle Challenge - Cluster-Based - Six regions')
plt.axis('off')

plt.show()

# %% [markdown]
# ## Example - Seven regions:

# %%
# ret: Sum of the squared distance from each point to its centers.
# labels: The labels of each pixel in the image.
# centers: Array with the centroids.
ret, label, centers = cv2.kmeans(vectorized_image, 7, None, CRITERIA, 10, cv2.KMEANS_RANDOM_CENTERS)
centers = np.uint8(centers)
print(centers)
# Out:
# [[ 80  80  76]
#  [ 19  33  38]
#  [182 175 170]
#  [227 231 234]
#  [219 225 227]
#  [232 236 237]
#  [134 127 121]]

# %%
final_image = centers[label.flatten()]
final_image = final_image.reshape(image.shape)

plt.imshow(final_image)
plt.title('Eagle Challenge - Cluster-Based - Seven regions')
plt.axis('off')

plt.show()
